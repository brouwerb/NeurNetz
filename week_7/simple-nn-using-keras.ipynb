# %%
import numpy as np
import pylab
#from keras.models import Sequential
#from keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
N=5000
x1 = 10*np.random.rand(N)-5*np.ones(N)  # random numbers [-5,5]
x2 = 10*np.random.rand(N)-5*np.ones(N)

ytrain=np.zeros(N)
for i in range(N):
    ytrain[i]=1+np.sign(x1[i]*x2[i])/2

# %%
net=Sequential()
net.add(Dense(4,input_shape=(2,),activation='relu'))
net.add(Dense(4,activation='relu'))
#net.add(Dense(10,activation='relu'))
net.add(Dense(1,activation='linear'))
net.compile(loss='mean_squared_error', optimizer='adam')
x=np.transpose((x1,x2))
# Out:
# 2022-12-07 21:11:53.454390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-07 21:12:12.079351: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-12-07 21:12:12.079384: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
ypredict=np.ravel(net.predict_on_batch(x))
pylab.scatter(x1,x2,c=ypredict)
pylab.show()

# %%
net.fit(x, ytrain, batch_size=100, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 1s 6ms/step - loss: 1.3612 - val_loss: 1.0183
# Epoch 2/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.8275 - val_loss: 0.7212
# Epoch 3/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.6219 - val_loss: 0.5724
# Epoch 4/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5067 - val_loss: 0.4649
# Epoch 5/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4174 - val_loss: 0.3807
# Epoch 6/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3388 - val_loss: 0.3029
# Epoch 7/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2715 - val_loss: 0.2474
# Epoch 8/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2259 - val_loss: 0.2114
# Epoch 9/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1953 - val_loss: 0.1866
# Epoch 10/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1745 - val_loss: 0.1695
# Epoch 11/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1601 - val_loss: 0.1578
# Epoch 12/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1499 - val_loss: 0.1489
# Epoch 13/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1418 - val_loss: 0.1416
# Epoch 14/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1350 - val_loss: 0.1366
# Epoch 15/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1294 - val_loss: 0.1310
# Epoch 16/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1248 - val_loss: 0.1273
# Epoch 17/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1212 - val_loss: 0.1240
# Epoch 18/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1180 - val_loss: 0.1209
# Epoch 19/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1152 - val_loss: 0.1183
# Epoch 20/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1127 - val_loss: 0.1161
# Epoch 21/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1104 - val_loss: 0.1136
# Epoch 22/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.1116
# Epoch 23/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1064 - val_loss: 0.1094
# Epoch 24/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1046 - val_loss: 0.1071
# Epoch 25/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1029 - val_loss: 0.1048
# Epoch 26/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1013 - val_loss: 0.1029
# Epoch 27/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0996 - val_loss: 0.1012
# Epoch 28/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0981 - val_loss: 0.0989
# Epoch 29/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0962 - val_loss: 0.0966
# Epoch 30/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0944 - val_loss: 0.0949
# Epoch 31/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0927 - val_loss: 0.0935
# Epoch 32/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0904 - val_loss: 0.0919
# Epoch 33/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0884 - val_loss: 0.0899
# Epoch 34/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0863 - val_loss: 0.0876
# Epoch 35/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0842 - val_loss: 0.0839
# Epoch 36/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0819 - val_loss: 0.0808
# Epoch 37/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0794 - val_loss: 0.0766
# Epoch 38/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0769 - val_loss: 0.0727
# Epoch 39/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0749 - val_loss: 0.0692
# Epoch 40/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0732 - val_loss: 0.0671
# Epoch 41/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.0623
# Epoch 42/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0685 - val_loss: 0.0606
# Epoch 43/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0661 - val_loss: 0.0591
# Epoch 44/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0636 - val_loss: 0.0563
# Epoch 45/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0608 - val_loss: 0.0544
# Epoch 46/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0584 - val_loss: 0.0532
# Epoch 47/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0569 - val_loss: 0.0520
# Epoch 48/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0560 - val_loss: 0.0512
# Epoch 49/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0548 - val_loss: 0.0509
# Epoch 50/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0539 - val_loss: 0.0504

# %%
ypredict=np.ravel(net.predict_on_batch(x))
pylab.scatter(x1,x2,c=ypredict)
pylab.show()
