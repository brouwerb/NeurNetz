# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

xres = 1000
tr = 200
c = 20
tres = 1.5/(xres*c)
wav = np.zeros([tr, xres])

XX, YY = np.meshgrid(x0, np.linspace(0, tres*tr, tr))

x0 = np.linspace(0, 1, xres)
wav[0] = (5*np.sin(4*np.pi*x0))
# wav.append([])
# for i in len(wav[0]):
print(wav)
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(XX, YY, wav)
display(fig)
# Out:
# [[ 0.00000000e+00  6.28930892e-02  1.25776227e-01 ... -1.25776227e-01
#   -6.28930892e-02 -2.44929360e-15]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
